# %% [markdown]
# ### Broadcasting Operators

# %%
import pandas as pd

# %%
nba = pd.read_csv('nba.csv')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba['Age'].add(5)
nba['Age'] + 5

nba['Salary'].sub(50000)
nba['Salary'] - 50000
# Out:
# 0      7680337.0
# 1      6746117.0
# 2            NaN
# 3      1098640.0
# 4      4950000.0
#          ...
# 453    2383333.0
# 454     850000.0
# 455    2850000.0
# 456     897276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba['Weight'].mul(0.45)
nba['Weight in Kilograms'] = nba['Weight']*0.45
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms
# 0              Texas  7730337.0                81.00
# 1          Marquette  6796117.0               105.75
# 2  Boston University        NaN                92.25
# 3      Georgia State  1148640.0                83.25
# 4                NaN  5000000.0               103.95

# %%
nba['Salary'].divide(1000000)
nba['Salary in Millions'] = nba['Salary']/1000000
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0                81.00            7.730337
# 1          Marquette  6796117.0               105.75            6.796117
# 2  Boston University        NaN                92.25                 NaN
# 3      Georgia State  1148640.0                83.25            1.148640
# 4                NaN  5000000.0               103.95            5.000000

# %% [markdown]
# ### value_counts() Method

# %%
nba['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba['Position'].value_counts()
nba['Weight'].value_counts().head()
nba['Salary'].value_counts().head()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 16407500.0     5
# Name: Salary, dtype: int64

# %% [markdown]
# ### Drop Rows with Null Values

# %%
nba.isnull().sum()
# Out:
# Name                    1
# Team                    1
# Number                  1
# Position                1
# Age                     1
# Height                  1
# Weight                  1
# College                85
# Salary                 12
# Weight in Kilograms     1
# Salary in Millions     12
# dtype: int64

# %%
nba.dropna()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Weight in Kilograms  Salary in Millions
# 0            Texas  7730337.0                81.00            7.730337
# 1        Marquette  6796117.0               105.75            6.796117
# 3    Georgia State  1148640.0                83.25            1.148640
# 6              LSU  1170960.0               105.75            1.170960
# 7          Gonzaga  2165160.0               107.10            2.165160
# ..             ...        ...                  ...                 ...
# 449           Duke  1348440.0                92.70            1.348440
# 451         Dayton   981348.0                92.70            0.981348
# 452       Kentucky  2239800.0               105.30            2.239800
# 453         Butler  2433333.0                91.35            2.433333
# 456         Kansas   947276.0               103.95            0.947276
#
# [364 rows x 11 columns]

# %%
nba.dropna(how = 'all', inplace = True)

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary  Weight in Kilograms  Salary in Millions
# 452  2239800.0               105.30            2.239800
# 453  2433333.0                91.35            2.433333
# 454   900000.0                80.55            0.900000
# 455  2900000.0               115.20            2.900000
# 456   947276.0               103.95            0.947276

# %%
nba.dropna(subset = ['College', 'Salary'])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Weight in Kilograms  Salary in Millions
# 0            Texas  7730337.0                81.00            7.730337
# 1        Marquette  6796117.0               105.75            6.796117
# 3    Georgia State  1148640.0                83.25            1.148640
# 6              LSU  1170960.0               105.75            1.170960
# 7          Gonzaga  2165160.0               107.10            2.165160
# ..             ...        ...                  ...                 ...
# 449           Duke  1348440.0                92.70            1.348440
# 451         Dayton   981348.0                92.70            0.981348
# 452       Kentucky  2239800.0               105.30            2.239800
# 453         Butler  2433333.0                91.35            2.433333
# 456         Kansas   947276.0               103.95            0.947276
#
# [364 rows x 11 columns]

# %% [markdown]
# ### fillna() Method

# %%
nba['Salary'].fillna(0, inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0                81.00            7.730337
# 1          Marquette  6796117.0               105.75            6.796117
# 2  Boston University        0.0                92.25                 NaN
# 3      Georgia State  1148640.0                83.25            1.148640
# 4                NaN  5000000.0               103.95            5.000000

# %%
nba['College'].fillna('No College', inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Weight in Kilograms  Salary in Millions
# 0              Texas  7730337.0                81.00            7.730337
# 1          Marquette  6796117.0               105.75            6.796117
# 2  Boston University        0.0                92.25                 NaN
# 3      Georgia State  1148640.0                83.25            1.148640
# 4         No College  5000000.0               103.95            5.000000

# %% [markdown]
# ### astype() Method

# %%
nba = pd.read_csv('nba.csv').dropna(how = 'all')
nba['Salary'].fillna(0, inplace = True)
nba['College'].fillna('No College', inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
#
#         College     Salary
# 452    Kentucky  2239800.0
# 453      Butler  2433333.0
# 454  No College   900000.0
# 455  No College  2900000.0
# 456      Kansas   947276.0

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
integer_columns = ['Number', 'Age', 'Weight', 'Salary']
for column in integer_columns:
    nba[column] = nba[column].astype('int')
nba.dtypes
# Out:
# Name        object
# Team        object
# Number       int32
# Position    object
# Age          int32
# Height      object
# Weight       int32
# College     object
# Salary       int32
# dtype: object

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2   John Holland  Boston Celtics      30       SG   27    6-5     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4         No College  5000000

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int32
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: int32(4), object(5)
# memory usage: 28.6+ KB

# %%
nba['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba['Position'] = nba['Position'].astype('category')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int32
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: category(1), int32(4), object(4)
# memory usage: 25.6+ KB

# %%
nba['Team'] = nba['Team'].astype('category')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int32
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: category(2), int32(4), object(3)
# memory usage: 23.8+ KB
